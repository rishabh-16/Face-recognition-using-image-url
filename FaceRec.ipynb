# %%
import models
from models import get_model
import utils
from utils import *

# %%
model = get_model()

# %%
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# Set layer weights of the model
for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])

# %%
store_faces()
# Out:
# Enter url of the image
# https://lh3.googleusercontent.com/q5Txl5NRpX86PaFIKcd0MvGcBTg-fe2bIpq3s-lWNw950Y-ADusk4uDnRCsOIJz8DGzIE4U2CltAtpgNyoodKV2P-qQxuGThn982Bnx9y_qTYfhQRYP1Air7PFwlu8NRE6QV2-nSIajTGgp6RFIp-aOphX5gUzbmzyhyizcQfMUYTLjg0JMqWWs3JkcO-B3W1m656LQhcyzghYbveTzT_hsmAG09F3cy4IFRUg7ZorJiINBDwMHARmUM0reJD7uYz4drEuT0Ow5H-eTEei2W8-K4Fn1DBvaVj9bFNWs2hhmqi0B5OTG6e-za3xkqzMHCB-6jzUliGvRrqMd1JK7dbbCvDVG_MYrsQNhkolFtql1mTA_jvzBZtHxH1Aazz2gTmtGBns5IH6XJf_GE3CRIwUGhu8pFbbMxqbvs4kYMNIe1V2vyaCZKEQL3VYolh2LdjvFk2dweBXMQ-w3mrlF3YfVSkdsAC4S9iNVfrYm_9hCrcKxfuVM2PeXsHXTuXL9EuQ9piXCEFAdFAKcrHMDrUeud7Iy3o5DFmNcD1q0bsd-gAqXpE7-hKLmMCrgzC-woUBETJN-aKuHaAZQqVxnV5p7mDnUbWF6eDUssMrAodhKE=s919-w919-h460-no
# Yash
# Aayush
# Abhishek
# Rishabh

# %%
input_embeddings = create_input_image_embeddings(model)
recognize_faces_in_image(input_embeddings, model, verbose = 0)
# Out:
# Enter URL of the image
# https://lh3.googleusercontent.com/GeIQDivJNfw8OMjAMVRPXRZZ3uJGvigKa9N9yNVT0qZDBaGISWwodC5s_D_YzMyxRxWoo54jeDHi7Ln66Cq0Ij7pTiKcIJtSml6kdTm2EO4ZMqly8uBySO1xf5WosbR8ro55rWZ_AjOEa2DVUoHifRpdLJTZoG_-dyApdWvymzIeWvnB8i4J1wvCEz0PrZof8FaF3b2nSAzm0rWn_qfsiBcE5j3Jtdp0RPvfTUdeUBA2cmhL-79V3LLQog9hnTcx-F3KDdylhiQ1_X-fmES2XzHuoZ7fEKor5cNmHmfE1oHoWZuUWYt3ejvt4L1EYA0fp6dme78Gv4spa4DdDAqFCtpkhepfJgUoQy_Y-KdH21RiZ09HikDf2Sapd_ust_UnyaT9Hik6nY2GX29HAaF8bc6e387NiW2pt3tdO6r1AiBKCaYLTT7cSY19CwkpcAz-a93TSYp7BsO8_6pstTo9-yyiP74ND4vVWQzWdfwv8XN83C0-KBMocqL6ypwhxsAh0Y41XOs9BerglpbObbExsBKDNmsOI2m6rvEMQlTXnp-GYS1pZrCL6oxjBiHkS3Tseo-ztWlGNYrJrM80pP9t0aoh7BGvDIsMzfgVOwFxHgf3wmoVuylV=s919-w919-h460-no
